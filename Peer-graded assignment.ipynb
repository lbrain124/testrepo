# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Lenae Brainard__
# Analyst

# %% [markdown]
# *I am interested in data science because it can beused to optimize and solve problems in any industry, and the field of study of data science itself aligns with the way the human brain processes information, which is kind of interesting.*

# %% [markdown]
# ### In the next cell, the code will simply print hello world.

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# | This          | Table             |~~Is Useless~~                                                          |
# | ------------- |:----------------: | ---------------------------------------------------------------------: |
# | Link to       | github cheatsheet | (https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)     |
